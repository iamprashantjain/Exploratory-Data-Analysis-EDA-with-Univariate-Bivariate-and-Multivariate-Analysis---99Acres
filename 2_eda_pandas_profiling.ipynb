# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Load your dataset
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# Create the ProfileReport object
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Generate the report
profile.to_file("output_report.html")

# %% [markdown]
# ## data overview

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## overview on specific column

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## bivariate analysis b/w 2 columns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## corelation b/w all numerical columns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## missing values

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Alerts

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#100 days ml playlist - specific video
#detailed library alternative to pandas profiling
